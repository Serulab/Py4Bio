# %% [markdown]
# Python for Bioinformatics
# -----------------------------
#
# ![title](https://s3.amazonaws.com/py4bio/tapabiosmall.png)
#
# This Jupyter notebook is intented to be used alongside the book [Python for Bioinformatics](http://py3.us/)

# %% [markdown]
# Chapter 23: DNA Mutations with Restrictions
# -------------

# %% [markdown]
# **Note:** The code in this chapter needs Biopython 1.69. It was not included in the first print of the book because this Biopython version was not available. The full source code in the [GitHub repository](https://github.com/Serulab/Py4Bio). This version is adapted to work in Jupyter Notebook.

# %%
# !pip install biopython
# Out:
# Collecting biopython
#   Downloading biopython-1.70.tar.gz (15.7MB)
#     100% |################################| 15.7MB 89kB/s  eta 0:00:01
# Requirement already satisfied: numpy in /home/nbcommon/anaconda3_431/lib/python3.6/site-packages (from biopython)
# Building wheels for collected packages: biopython
# done
#   Stored in directory: /home/nbuser/.cache/pip/wheels/b6/3d/13/02803d941d2488e0920c7f482ddebe949cb6f346d9fe205bf9
# Successfully built biopython
# Installing collected packages: biopython
# Successfully installed biopython-1.70

# %%
'''Given a DNA sequence of a polypeptide, this program
generates alternative DNA sequences that code for the same
polypeptide but that can be sorted out by DNA restriction.
Requires Biopython >= 1.69
Author: Sebastian Bassi (sbassi@genesdigitales.com)'''

from Bio import Seq
from Bio.Alphabet import IUPAC
from Bio import Restriction
from Bio.Data import CodonTable
from jinja2 import Template

TABLE_ID = 1
ALLOWED_MUTATIONS = 2

mutation_tpl = """Original Sequence: {{dna_input}}
Peptide: {{ori_pep}}

Restriction map for original sequence:

{{ori_map}}

=========================
{% for item in bakpeps_out %}

Original sequence enzymes: {{oname}}

{{item.graph}}

Proposed sequence enzymes: {{item.pames}}
Enzimes only in original sequence: {{item.o}}
Enzimes only in proposed sequence: {{item.p}}
=========================
{% endfor %}"""

def backtrans(ori_pep, table_id=1):
    """
    Function to make backtranslation (from peptide to DNA)
    This function needs the peptide sequence and the code of
    translation table. Code number is the same as posted in:
    http://www.ncbi.nlm.nih.gov/Taxonomy/Utils/wprintgc.cgi
    """
    def recurs(order, pos):
        for letter in bt[order[pos]]:
            if pos == len(order) - 1:
                yield letter
                continue
            for prox in recurs(order, pos+1):
                yield (letter + prox)

    def combine(order):
        ordened = set()
        for frase in recurs(order, 0):
            ordened.add(frase)
        return ordened

    t = CodonTable.generic_by_id[table_id]
    bt = dict()
    for a1 in "ATCG" :
        for a2 in "ATCG" :
            for a3 in "ATCG" :
                codon = a1 + a2 + a3
                try:
                    amino = t.forward_table[codon]
                except KeyError:
                    assert codon in t.stop_codons
                    continue
                try:
                    bt[amino].append(codon)
                except KeyError:
                    bt[amino] = [codon]
    return list(combine(ori_pep))

def seqcomp(s1, s2):
    """
    Compares 2 sequences and returns a value with
    how many differents elements they have.
    """
    p = len(s1)
    for x,y in zip(s1, s2): # Walk through 2 sequences.
        if x==y:
            p -= 1
    return p

input_dna = input('Enter DNA sequennce: ').upper()
dna = Seq.Seq(input_dna, IUPAC.unambiguous_dna)
# Translate DNA sequence.
ori_pep = dna.translate()
# Get all backtranslations.
bakpeps = backtrans(ori_pep, TABLE_ID)
# Make a restriction analysis for the orignal sequence.
analysis = Restriction.Analysis(Restriction.CommOnly, dna)
analysis.print_as('map')
ori_map = analysis.format_output()
# Store the enzymes that cut in the original sequence.
enz = list(analysis.with_sites().keys())
# Get a string out of the enzyme list, for printing.
oname = str(enz)[1:-1]
enz = set(enz)
bakpeps_out = []
for bakpep in bakpeps:
    tmp_d = {}
    if bakpep not in input_dna:
        # Make a restriction analysis for each sequence.
        analysis = Restriction.Analysis(Restriction.CommOnly,
                Seq.Seq(bakpep, IUPAC.unambiguous_dna))
        # Store the enzymes that cut in this sequence.
        enz_tmp = list(analysis.with_sites().keys())
        enz_tmp = set(enz_tmp)
        # Get the number of mutations in backpep sequence.
        y = seqcomp(input_dna, bakpep)
        if enz_tmp != enz and enz and y <= ALLOWED_MUTATIONS:
            analysis.print_as('map')
            tmp_d['pames'] = str(enz_tmp)[1:-1]
            tmp_d['graph'] = analysis.format_output()
            tmp_d['ori_seq'] = str(list(enz.difference(
                                        enz_tmp)))[1:-1]
            tmp_d['proposed_seq'] = str(list(
                        enz_tmp.difference(enz)))[1:-1]
            bakpeps_out.append(tmp_d)
template = Template(mutation_tpl)
render = template.render(dna_input=input_dna,
                         ori_pep=ori_pep,
                         ori_map=ori_map,
                         oname=oname,
                         bakpeps_out=bakpeps_out)
print(render)
# Out:
# Enter DNA sequennce: atacgctgtcatgca
# Original Sequence: ATACGCTGTCATGCA
# Peptide: IRCHA
#
# Restriction map for original sequence:
#
#    4 AbaSI
#    |
#    |     10 FatI
#    |     |
#    |     |11 CviAII
#    |     ||
#    |     ||12 FaiI
#    |     |||
#    |     ||| 14 Hin1II NlaIII FaeI HpyCH4V Hsp92II
#    |     ||| |
# ATACGCTGTCATGCA
# |||||||||||||||
# TATGCGACAGTACGT
# 1                           15
#
#
#    Enzymes which do not cut the sequence.
#
# FspEI     AccII     AciI      AfaI      AluBI     AluI      AoxI      AspLEI
# BfaI      BfuCI     Bsh1236I  BshFI     BsiSI     BsnI      Bsp143I   BspACI
# BspANI    BspFNI    BssMI     BstFNI    BstHHI    BstKTI    BstMBI    BstUI
# BsuRI     CfoI      Csp6I     CviJI     CviKI_1   CviQI     DpnI      DpnII
# FspBI     GlaI      HaeIII    HapII     HhaI      Hin6I     HinP1I    HpaII
# HpyCH4IV  HpySE526I HspAI     Kzo9I     LpnPI     MaeI      MaeII     MalI
# MboI      MluCI     MnlI      MseI      MspI      MspJI     MvnI      NdeII
# RsaI      RsaNI     SaqAI     Sau3AI    SetI      SgeI      Sse9I     SsiI
# SspMI     TaiI      TaqI      TasI      Tru1I     Tru9I     XspI      AclWI
# AgsI      AjnI      Alw26I    AlwI      ApeKI     AspS9I    AsuC2I    AsuHPI
# AvaII     BbvI      BccI      BceAI     BciT130I  BcnI      BcoDI     BisI
# BlsI      Bme1390I  Bme18I    BmgT120I  BmrFI     BmsI      BpuMI     Bse1I
# BseBI     BseGI     BseMII    BseNI     BseXI     BslFI     BsmAI     BsmFI
# BspCNI    BspPI     BsrI      Bst2UI    Bst4CI    BstDEI    BstF5I    BstMAI
# BstNI     BstSCI    BstV1I    BtsCI     BtsIMutI  Cfr13I    CseI      DdeI
# Eco47I    EcoRII    FaqI      FauI      Fnu4HI    FokI      Fsp4HI    GluI
# HgaI      HinfI     HphI      Hpy188I   Hpy99I    HpyAV     HpyCH4III HpyF3I
# LmnI      Lsp1109I  LweI      MaeIII    MboII     MlyI      MspR9I    MvaI
# NciI      NmuCI     PfeI      PkrI      PleI      PpsI      Psp6I     PspGI
# PspPI     SatI      Sau96I    SchI      ScrFI     SfaNI     SinI      StyD4I
# TaaI      TauI      TfiI      TscAI     TseFI     TseI      Tsp45I    TspDTI
# TspGWI    TspRI     VpaK11BI  AanI      AatII     Acc16I    Acc36I    Acc65I
# AccB1I    AccBSI    AccI      AccIII    AclI      AcoI      AcsI      AcuI
# AcvI      AcyI      AfeI      AflII     AflIII    AgeI      AhlI      AjiI
# Alw21I    Alw44I    Ama87I    Aor13HI   Aor51HI   ApaI      ApaLI     ApoI
# AseI      AsiGI     Asp718I   AspA2I    AsuII     AsuNHI    AvaI      AvrII
# BaeGI     BalI      BamHI     BanI      BanII     BauI      BbrPI     BbsI
# Bbv12I    BciVI     BclI      BcuI      BfmI      BfoI      BfrI      BfuAI
# BfuI      BglII     BlnI      BmcAI     BmeT110I  BmgBI     BmiI      BmrI
# BmtI      BmuI      BpiI      BpmI      Bpu14I    BpuEI     Bsa29I    BsaAI
# BsaHI     BsaI      BsaJI     BsaWI     Bse118I   Bse3DI    BseAI     BseCI
# BseDI     BseMI     BsePI     BseRI     BseSI     BseX3I    BseYI     BsgI
# Bsh1285I  BshNI     BshTI     BshVI     BsiEI     BsiHKAI   BsiHKCI   BsiWI
# BsmBI     BsmI      Bso31I    BsoBI     Bsp119I   Bsp120I   Bsp1286I  Bsp13I
# Bsp1407I  Bsp19I    Bsp68I    BspDI     BspEI     BspHI     BspLI     BspMAI
# BspMI     BspOI     BspT104I  BspT107I  BspTI     BspTNI    BsrBI     BsrDI
# BsrFI     BsrGI     BssAI     BssECI    BssHII    BssNAI    BssNI     BssSI
# BssT1I    Bst1107I  Bst2BI    Bst6I     BstACI    BstAFI    BstAUI    BstBAI
# BstBI     BstC8I    BstDSI    BstH2I    BstMCI    BstNSI    BstSFI    BstSLI
# BstSNI    BstV2I    BstX2I    BstYI     BstZ17I   BstZI     Bsu15I    BsuI
# BsuTUI    BtgI      BtgZI     BtrI      BtsI      BtuMI     BveI      Cac8I
# CciI      Cfr10I    Cfr42I    Cfr9I     ClaI      CspAI     DinI      DraI
# EaeI      EagI      Eam1104I  EarI      EciI      Ecl136II  EclXI     Eco105I
# Eco130I   Eco147I   Eco24I    Eco31I    Eco32I    Eco47III  Eco52I    Eco53kI
# Eco57I    Eco72I    Eco88I    EcoICRI   EcoRI     EcoRV     EcoT14I   EcoT22I
# EcoT38I   EgeI      EheI      ErhI      Esp3I     FauNDI    FbaI      FblI
# FriOI     FspI      GsaI      GsuI      HaeII     Hin1I     HincII    HindII
# HindIII   HpaI      Hpy166II  Hpy188III Hpy8I     Hsp92I    KasI      Kpn2I
# KpnI      KroI      Ksp22I    KspAI     KspI      MbiI      MfeI      MflI
# MhlI      MlsI      MluI      MluNI     Mly113I   MmeI      Mox20I    Mph1103I
# MroI      MroNI     MscI      Msp20I    MspA1I    MspCI     MunI      Mva1269I
# NaeI      NarI      NcoI      NdeI      NgoMIV    NheI      NlaIV     NmeAIII
# NruI      NsbI      NsiI      NspI      NspV      PaeI      PaeR7I    PagI
# PauI      PceI      PciI      PctI      PdiI      Pfl23II   PinAI     Ple19I
# PluTI     PmaCI     PmlI      Ppu21I    PscI      PshBI     PsiI      Psp124BI
# Psp1406I  PspCI     PspFI     PspLI     PspN4I    PspOMI    PstI      PsuI
# PteI      PvuI      PvuII     RruI      SacI      SacII     SalI      ScaI
# SduI      SfcI      SfoI      Sfr274I   Sfr303I   SfuI      SgrBI     SlaI
# SmaI      SmlI      SmoI      SnaBI     SpeI      SphI      SseBI     SspDI
# SspI      SstI      StuI      StyI      TaqII     TatI      TspMI     Vha464I
# VneI      VspI      XapI      XbaI      XceI      XhoI      XmaI      XmaJI
# XmiI      ZraI      ZrmI      Zsp2I     AarI      AxyI      BbvCI     BlpI
# Bpu10I    Bpu1102I  Bse21I    Bsp1720I  BspQI     BstEII    BstPI     Bsu36I
# CpoI      CsiI      CspI      Eco81I    Eco91I    EcoO109I  EcoO65I   KflI
# LguI      MabI      PasI      PciSI     PfoI      PpuMI     Psp5II    PspEI
# PspPPI    Rsr2I     RsrII     SapI      SexAI     AbsI      AscI      AsiSI
# CciNI     FseI      FspAI     MauBI     MreI      MssI      NotI      PacI
# PalAI     PmeI      PspXI     RgaI      RigI      SbfI      SdaI      SfaAI
# SgfI      SgrAI     SgrDI     SgsI      SmiI      SrfI      Sse8387I  SwaI
# AdeI      AlwNI     CaiI      DraIII    MteI      PflFI     PstNI     PsyI
# Tth111I   AleI      Asp700I   BoxI      BsaBI     Bse8I     BseJI     BstPAI
# MroXI     MslI      OliI      PdmI      PshAI     RseI      SmiMI     XmnI
# AccB7I    AfiI      AhdI      BaeI      BglI      BmeRI     BplI      BsaXI
# Bsc4I     BseLI     BslI      BstAPI    BstENI    BstMWI    DriI      Eam1105I
# EcoNI     FalI      HpyF10VI  MwoI      PflMI     Van91I    XagI      AasI
# BcgI      BstXI     CspCI     DrdI      DseDI     AloI      ArsI      BarI
# PcsI      PsrI      SfiI      AjuI      XcmI
#
#
# =========================
#
#
# Original sequence enzymes: Hin1II, NlaIII, FaeI, AbaSI, CviAII, FaiI, FatI, HpyCH4V, Hsp92II
#
#    4 AciI AbaSI BspACI SsiI
#    |
#    | 6 MspA1I
#    | |
#    | | 8 TseFI NmuCI Tsp45I MaeIII
#    | | |
#    | | |      15 AbaSI
#    | | |      |
# ATCCGCTGTCACGCA
# |||||||||||||||
# TAGGCGACAGTGCGT
# 1                           15
#
#
#    Enzymes which do not cut the sequence.
#
# FspEI     AccII     AfaI      AluBI     AluI      AoxI      AspLEI    BfaI
# BfuCI     Bsh1236I  BshFI     BsiSI     BsnI      Bsp143I   BspANI    BspFNI
# BssMI     BstFNI    BstHHI    BstKTI    BstMBI    BstUI     BsuRI     CfoI
# Csp6I     CviAII    CviJI     CviKI_1   CviQI     DpnI      DpnII     FaeI
# FaiI      FatI      FspBI     GlaI      HaeIII    HapII     HhaI      Hin1II
# Hin6I     HinP1I    HpaII     HpyCH4IV  HpyCH4V   HpySE526I Hsp92II   HspAI
# Kzo9I     LpnPI     MaeI      MaeII     MalI      MboI      MluCI     MnlI
# MseI      MspI      MspJI     MvnI      NdeII     NlaIII    RsaI      RsaNI
# SaqAI     Sau3AI    SetI      SgeI      Sse9I     SspMI     TaiI      TaqI
# TasI      Tru1I     Tru9I     XspI      AclWI     AgsI      AjnI      Alw26I
# AlwI      ApeKI     AspS9I    AsuC2I    AsuHPI    AvaII     BbvI      BccI
# BceAI     BciT130I  BcnI      BcoDI     BisI      BlsI      Bme1390I  Bme18I
# BmgT120I  BmrFI     BmsI      BpuMI     Bse1I     BseBI     BseGI     BseMII
# BseNI     BseXI     BslFI     BsmAI     BsmFI     BspCNI    BspPI     BsrI
# Bst2UI    Bst4CI    BstDEI    BstF5I    BstMAI    BstNI     BstSCI    BstV1I
# BtsCI     BtsIMutI  Cfr13I    CseI      DdeI      Eco47I    EcoRII    FaqI
# FauI      Fnu4HI    FokI      Fsp4HI    GluI      HgaI      HinfI     HphI
# Hpy188I   Hpy99I    HpyAV     HpyCH4III HpyF3I    LmnI      Lsp1109I  LweI
# MboII     MlyI      MspR9I    MvaI      NciI      PfeI      PkrI      PleI
# PpsI      Psp6I     PspGI     PspPI     SatI      Sau96I    SchI      ScrFI
# SfaNI     SinI      StyD4I    TaaI      TauI      TfiI      TscAI     TseI
# TspDTI    TspGWI    TspRI     VpaK11BI  AanI      AatII     Acc16I    Acc36I
# Acc65I    AccB1I    AccBSI    AccI      AccIII    AclI      AcoI      AcsI
# AcuI      AcvI      AcyI      AfeI      AflII     AflIII    AgeI      AhlI
# AjiI      Alw21I    Alw44I    Ama87I    Aor13HI   Aor51HI   ApaI      ApaLI
# ApoI      AseI      AsiGI     Asp718I   AspA2I    AsuII     AsuNHI    AvaI
# AvrII     BaeGI     BalI      BamHI     BanI      BanII     BauI      BbrPI
# BbsI      Bbv12I    BciVI     BclI      BcuI      BfmI      BfoI      BfrI
# BfuAI     BfuI      BglII     BlnI      BmcAI     BmeT110I  BmgBI     BmiI
# BmrI      BmtI      BmuI      BpiI      BpmI      Bpu14I    BpuEI     Bsa29I
# BsaAI     BsaHI     BsaI      BsaJI     BsaWI     Bse118I   Bse3DI    BseAI
# BseCI     BseDI     BseMI     BsePI     BseRI     BseSI     BseX3I    BseYI
# BsgI      Bsh1285I  BshNI     BshTI     BshVI     BsiEI     BsiHKAI   BsiHKCI
# BsiWI     BsmBI     BsmI      Bso31I    BsoBI     Bsp119I   Bsp120I   Bsp1286I
# Bsp13I    Bsp1407I  Bsp19I    Bsp68I    BspDI     BspEI     BspHI     BspLI
# BspMAI    BspMI     BspOI     BspT104I  BspT107I  BspTI     BspTNI    BsrBI
# BsrDI     BsrFI     BsrGI     BssAI     BssECI    BssHII    BssNAI    BssNI
# BssSI     BssT1I    Bst1107I  Bst2BI    Bst6I     BstACI    BstAFI    BstAUI
# BstBAI    BstBI     BstC8I    BstDSI    BstH2I    BstMCI    BstNSI    BstSFI
# BstSLI    BstSNI    BstV2I    BstX2I    BstYI     BstZ17I   BstZI     Bsu15I
# BsuI      BsuTUI    BtgI      BtgZI     BtrI      BtsI      BtuMI     BveI
# Cac8I     CciI      Cfr10I    Cfr42I    Cfr9I     ClaI      CspAI     DinI
# DraI      EaeI      EagI      Eam1104I  EarI      EciI      Ecl136II  EclXI
# Eco105I   Eco130I   Eco147I   Eco24I    Eco31I    Eco32I    Eco47III  Eco52I
# Eco53kI   Eco57I    Eco72I    Eco88I    EcoICRI   EcoRI     EcoRV     EcoT14I
# EcoT22I   EcoT38I   EgeI      EheI      ErhI      Esp3I     FauNDI    FbaI
# FblI      FriOI     FspI      GsaI      GsuI      HaeII     Hin1I     HincII
# HindII    HindIII   HpaI      Hpy166II  Hpy188III Hpy8I     Hsp92I    KasI
# Kpn2I     KpnI      KroI      Ksp22I    KspAI     KspI      MbiI      MfeI
# MflI      MhlI      MlsI      MluI      MluNI     Mly113I   MmeI      Mox20I
# Mph1103I  MroI      MroNI     MscI      Msp20I    MspCI     MunI      Mva1269I
# NaeI      NarI      NcoI      NdeI      NgoMIV    NheI      NlaIV     NmeAIII
# NruI      NsbI      NsiI      NspI      NspV      PaeI      PaeR7I    PagI
# PauI      PceI      PciI      PctI      PdiI      Pfl23II   PinAI     Ple19I
# PluTI     PmaCI     PmlI      Ppu21I    PscI      PshBI     PsiI      Psp124BI
# Psp1406I  PspCI     PspFI     PspLI     PspN4I    PspOMI    PstI      PsuI
# PteI      PvuI      PvuII     RruI      SacI      SacII     SalI      ScaI
# SduI      SfcI      SfoI      Sfr274I   Sfr303I   SfuI      SgrBI     SlaI
# SmaI      SmlI      SmoI      SnaBI     SpeI      SphI      SseBI     SspDI
# SspI      SstI      StuI      StyI      TaqII     TatI      TspMI     Vha464I
# VneI      VspI      XapI      XbaI      XceI      XhoI      XmaI      XmaJI
# XmiI      ZraI      ZrmI      Zsp2I     AarI      AxyI      BbvCI     BlpI
# Bpu10I    Bpu1102I  Bse21I    Bsp1720I  BspQI     BstEII    BstPI     Bsu36I
# CpoI      CsiI      CspI      Eco81I    Eco91I    EcoO109I  EcoO65I   KflI
# LguI      MabI      PasI      PciSI     PfoI      PpuMI     Psp5II    PspEI
# PspPPI    Rsr2I     RsrII     SapI      SexAI     AbsI      AscI      AsiSI
# CciNI     FseI      FspAI     MauBI     MreI      MssI      NotI      PacI
# PalAI     PmeI      PspXI     RgaI      RigI      SbfI      SdaI      SfaAI
# SgfI      SgrAI     SgrDI     SgsI      SmiI      SrfI      Sse8387I  SwaI
# AdeI      AlwNI     CaiI      DraIII    MteI      PflFI     PstNI     PsyI
# Tth111I   AleI      Asp700I   BoxI      BsaBI     Bse8I     BseJI     BstPAI
# MroXI     MslI      OliI      PdmI      PshAI     RseI      SmiMI     XmnI
# AccB7I    AfiI      AhdI      BaeI      BglI      BmeRI     BplI      BsaXI
# Bsc4I     BseLI     BslI      BstAPI    BstENI    BstMWI    DriI      Eam1105I
# EcoNI     FalI      HpyF10VI  MwoI      PflMI     Van91I    XagI      AasI
# BcgI      BstXI     CspCI     DrdI      DseDI     AloI      ArsI      BarI
# PcsI      PsrI      SfiI      AjuI      XcmI
#
#
# Proposed sequence enzymes: BspACI, TseFI, AbaSI, NmuCI, Tsp45I, MaeIII, AciI, SsiI, MspA1I
# Enzimes only in original sequence:
# Enzimes only in proposed sequence:
# =========================
#
#
# Original sequence enzymes: Hin1II, NlaIII, FaeI, AbaSI, CviAII, FaiI, FatI, HpyCH4V, Hsp92II
#
#    4 AbaSI
#    |
#    | 6 ApeKI TseI
#    | |
#    | |7 GluI Fsp4HI Fnu4HI SatI BisI
#    | ||
#    | ||8 PkrI BlsI
#    | |||
#    | ||| 10 FatI
#    | ||| |
#    | ||| |11 CviAII
#    | ||| ||
#    | ||| ||12 FaiI
#    | ||| |||
#    | ||| ||| 14 Hin1II NlaIII FaeI HpyCH4V Hsp92II
#    | ||| ||| |
# ATACGCTGCCATGCA
# |||||||||||||||
# TATGCGACGGTACGT
# 1                           15
#
#
#    Enzymes which do not cut the sequence.
#
# FspEI     AccII     AciI      AfaI      AluBI     AluI      AoxI      AspLEI
# BfaI      BfuCI     Bsh1236I  BshFI     BsiSI     BsnI      Bsp143I   BspACI
# BspANI    BspFNI    BssMI     BstFNI    BstHHI    BstKTI    BstMBI    BstUI
# BsuRI     CfoI      Csp6I     CviJI     CviKI_1   CviQI     DpnI      DpnII
# FspBI     GlaI      HaeIII    HapII     HhaI      Hin6I     HinP1I    HpaII
# HpyCH4IV  HpySE526I HspAI     Kzo9I     LpnPI     MaeI      MaeII     MalI
# MboI      MluCI     MnlI      MseI      MspI      MspJI     MvnI      NdeII
# RsaI      RsaNI     SaqAI     Sau3AI    SetI      SgeI      Sse9I     SsiI
# SspMI     TaiI      TaqI      TasI      Tru1I     Tru9I     XspI      AclWI
# AgsI      AjnI      Alw26I    AlwI      AspS9I    AsuC2I    AsuHPI    AvaII
# BbvI      BccI      BceAI     BciT130I  BcnI      BcoDI     Bme1390I  Bme18I
# BmgT120I  BmrFI     BmsI      BpuMI     Bse1I     BseBI     BseGI     BseMII
# BseNI     BseXI     BslFI     BsmAI     BsmFI     BspCNI    BspPI     BsrI
# Bst2UI    Bst4CI    BstDEI    BstF5I    BstMAI    BstNI     BstSCI    BstV1I
# BtsCI     BtsIMutI  Cfr13I    CseI      DdeI      Eco47I    EcoRII    FaqI
# FauI      FokI      HgaI      HinfI     HphI      Hpy188I   Hpy99I    HpyAV
# HpyCH4III HpyF3I    LmnI      Lsp1109I  LweI      MaeIII    MboII     MlyI
# MspR9I    MvaI      NciI      NmuCI     PfeI      PleI      PpsI      Psp6I
# PspGI     PspPI     Sau96I    SchI      ScrFI     SfaNI     SinI      StyD4I
# TaaI      TauI      TfiI      TscAI     TseFI     Tsp45I    TspDTI    TspGWI
# TspRI     VpaK11BI  AanI      AatII     Acc16I    Acc36I    Acc65I    AccB1I
# AccBSI    AccI      AccIII    AclI      AcoI      AcsI      AcuI      AcvI
# AcyI      AfeI      AflII     AflIII    AgeI      AhlI      AjiI      Alw21I
# Alw44I    Ama87I    Aor13HI   Aor51HI   ApaI      ApaLI     ApoI      AseI
# AsiGI     Asp718I   AspA2I    AsuII     AsuNHI    AvaI      AvrII     BaeGI
# BalI      BamHI     BanI      BanII     BauI      BbrPI     BbsI      Bbv12I
# BciVI     BclI      BcuI      BfmI      BfoI      BfrI      BfuAI     BfuI
# BglII     BlnI      BmcAI     BmeT110I  BmgBI     BmiI      BmrI      BmtI
# BmuI      BpiI      BpmI      Bpu14I    BpuEI     Bsa29I    BsaAI     BsaHI
# BsaI      BsaJI     BsaWI     Bse118I   Bse3DI    BseAI     BseCI     BseDI
# BseMI     BsePI     BseRI     BseSI     BseX3I    BseYI     BsgI      Bsh1285I
# BshNI     BshTI     BshVI     BsiEI     BsiHKAI   BsiHKCI   BsiWI     BsmBI
# BsmI      Bso31I    BsoBI     Bsp119I   Bsp120I   Bsp1286I  Bsp13I    Bsp1407I
# Bsp19I    Bsp68I    BspDI     BspEI     BspHI     BspLI     BspMAI    BspMI
# BspOI     BspT104I  BspT107I  BspTI     BspTNI    BsrBI     BsrDI     BsrFI
# BsrGI     BssAI     BssECI    BssHII    BssNAI    BssNI     BssSI     BssT1I
# Bst1107I  Bst2BI    Bst6I     BstACI    BstAFI    BstAUI    BstBAI    BstBI
# BstC8I    BstDSI    BstH2I    BstMCI    BstNSI    BstSFI    BstSLI    BstSNI
# BstV2I    BstX2I    BstYI     BstZ17I   BstZI     Bsu15I    BsuI      BsuTUI
# BtgI      BtgZI     BtrI      BtsI      BtuMI     BveI      Cac8I     CciI
# Cfr10I    Cfr42I    Cfr9I     ClaI      CspAI     DinI      DraI      EaeI
# EagI      Eam1104I  EarI      EciI      Ecl136II  EclXI     Eco105I   Eco130I
# Eco147I   Eco24I    Eco31I    Eco32I    Eco47III  Eco52I    Eco53kI   Eco57I
# Eco72I    Eco88I    EcoICRI   EcoRI     EcoRV     EcoT14I   EcoT22I   EcoT38I
# EgeI      EheI      ErhI      Esp3I     FauNDI    FbaI      FblI      FriOI
# FspI      GsaI      GsuI      HaeII     Hin1I     HincII    HindII    HindIII
# HpaI      Hpy166II  Hpy188III Hpy8I     Hsp92I    KasI      Kpn2I     KpnI
# KroI      Ksp22I    KspAI     KspI      MbiI      MfeI      MflI      MhlI
# MlsI      MluI      MluNI     Mly113I   MmeI      Mox20I    Mph1103I  MroI
# MroNI     MscI      Msp20I    MspA1I    MspCI     MunI      Mva1269I  NaeI
# NarI      NcoI      NdeI      NgoMIV    NheI      NlaIV     NmeAIII   NruI
# NsbI      NsiI      NspI      NspV      PaeI      PaeR7I    PagI      PauI
# PceI      PciI      PctI      PdiI      Pfl23II   PinAI     Ple19I    PluTI
# PmaCI     PmlI      Ppu21I    PscI      PshBI     PsiI      Psp124BI  Psp1406I
# PspCI     PspFI     PspLI     PspN4I    PspOMI    PstI      PsuI      PteI
# PvuI      PvuII     RruI      SacI      SacII     SalI      ScaI      SduI
# SfcI      SfoI      Sfr274I   Sfr303I   SfuI      SgrBI     SlaI      SmaI
# SmlI      SmoI      SnaBI     SpeI      SphI      SseBI     SspDI     SspI
# SstI      StuI      StyI      TaqII     TatI      TspMI     Vha464I   VneI
# VspI      XapI      XbaI      XceI      XhoI      XmaI      XmaJI     XmiI
# ZraI      ZrmI      Zsp2I     AarI      AxyI      BbvCI     BlpI      Bpu10I
# Bpu1102I  Bse21I    Bsp1720I  BspQI     BstEII    BstPI     Bsu36I    CpoI
# CsiI      CspI      Eco81I    Eco91I    EcoO109I  EcoO65I   KflI      LguI
# MabI      PasI      PciSI     PfoI      PpuMI     Psp5II    PspEI     PspPPI
# Rsr2I     RsrII     SapI      SexAI     AbsI      AscI      AsiSI     CciNI
# FseI      FspAI     MauBI     MreI      MssI      NotI      PacI      PalAI
# PmeI      PspXI     RgaI      RigI      SbfI      SdaI      SfaAI     SgfI
# SgrAI     SgrDI     SgsI      SmiI      SrfI      Sse8387I  SwaI      AdeI
# AlwNI     CaiI      DraIII    MteI      PflFI     PstNI     PsyI      Tth111I
# AleI      Asp700I   BoxI      BsaBI     Bse8I     BseJI     BstPAI    MroXI
# MslI      OliI      PdmI      PshAI     RseI      SmiMI     XmnI      AccB7I
# AfiI      AhdI      BaeI      BglI      BmeRI     BplI      BsaXI     Bsc4I
# BseLI     BslI      BstAPI    BstENI    BstMWI    DriI      Eam1105I  EcoNI
# FalI      HpyF10VI  MwoI      PflMI     Van91I    XagI      AasI      BcgI
# BstXI     CspCI     DrdI      DseDI     AloI      ArsI      BarI      PcsI
# PsrI      SfiI      AjuI      XcmI
#
#
# Proposed sequence enzymes: TseI, SatI, GluI, AbaSI, Fsp4HI, CviAII, FaiI, FaeI, FatI, HpyCH4V, Fnu4HI, PkrI, Hsp92II, ApeKI, BisI, BlsI, NlaIII, Hin1II
# Enzimes only in original sequence:
# Enzimes only in proposed sequence:
# =========================
#
#
# Original sequence enzymes: Hin1II, NlaIII, FaeI, AbaSI, CviAII, FaiI, FatI, HpyCH4V, Hsp92II
#
#    4 AbaSI
#    |
#    |     10 FatI
#    |     |
#    |     |11 CviAII
#    |     ||
#    |     ||12 FaiI
#    |     |||
#    |     ||| 14 Hin1II NlaIII FaeI Hsp92II
#    |     ||| |
# ATTCGCTGTCATGCC
# |||||||||||||||
# TAAGCGACAGTACGG
# 1                           15
#
#
#    Enzymes which do not cut the sequence.
#
# FspEI     AccII     AciI      AfaI      AluBI     AluI      AoxI      AspLEI
# BfaI      BfuCI     Bsh1236I  BshFI     BsiSI     BsnI      Bsp143I   BspACI
# BspANI    BspFNI    BssMI     BstFNI    BstHHI    BstKTI    BstMBI    BstUI
# BsuRI     CfoI      Csp6I     CviJI     CviKI_1   CviQI     DpnI      DpnII
# FspBI     GlaI      HaeIII    HapII     HhaI      Hin6I     HinP1I    HpaII
# HpyCH4IV  HpyCH4V   HpySE526I HspAI     Kzo9I     LpnPI     MaeI      MaeII
# MalI      MboI      MluCI     MnlI      MseI      MspI      MspJI     MvnI
# NdeII     RsaI      RsaNI     SaqAI     Sau3AI    SetI      SgeI      Sse9I
# SsiI      SspMI     TaiI      TaqI      TasI      Tru1I     Tru9I     XspI
# AclWI     AgsI      AjnI      Alw26I    AlwI      ApeKI     AspS9I    AsuC2I
# AsuHPI    AvaII     BbvI      BccI      BceAI     BciT130I  BcnI      BcoDI
# BisI      BlsI      Bme1390I  Bme18I    BmgT120I  BmrFI     BmsI      BpuMI
# Bse1I     BseBI     BseGI     BseMII    BseNI     BseXI     BslFI     BsmAI
# BsmFI     BspCNI    BspPI     BsrI      Bst2UI    Bst4CI    BstDEI    BstF5I
# BstMAI    BstNI     BstSCI    BstV1I    BtsCI     BtsIMutI  Cfr13I    CseI
# DdeI      Eco47I    EcoRII    FaqI      FauI      Fnu4HI    FokI      Fsp4HI
# GluI      HgaI      HinfI     HphI      Hpy188I   Hpy99I    HpyAV     HpyCH4III
# HpyF3I    LmnI      Lsp1109I  LweI      MaeIII    MboII     MlyI      MspR9I
# MvaI      NciI      NmuCI     PfeI      PkrI      PleI      PpsI      Psp6I
# PspGI     PspPI     SatI      Sau96I    SchI      ScrFI     SfaNI     SinI
# StyD4I    TaaI      TauI      TfiI      TscAI     TseFI     TseI      Tsp45I
# TspDTI    TspGWI    TspRI     VpaK11BI  AanI      AatII     Acc16I    Acc36I
# Acc65I    AccB1I    AccBSI    AccI      AccIII    AclI      AcoI      AcsI
# AcuI      AcvI      AcyI      AfeI      AflII     AflIII    AgeI      AhlI
# AjiI      Alw21I    Alw44I    Ama87I    Aor13HI   Aor51HI   ApaI      ApaLI
# ApoI      AseI      AsiGI     Asp718I   AspA2I    AsuII     AsuNHI    AvaI
# AvrII     BaeGI     BalI      BamHI     BanI      BanII     BauI      BbrPI
# BbsI      Bbv12I    BciVI     BclI      BcuI      BfmI      BfoI      BfrI
# BfuAI     BfuI      BglII     BlnI      BmcAI     BmeT110I  BmgBI     BmiI
# BmrI      BmtI      BmuI      BpiI      BpmI      Bpu14I    BpuEI     Bsa29I
# BsaAI     BsaHI     BsaI      BsaJI     BsaWI     Bse118I   Bse3DI    BseAI
# BseCI     BseDI     BseMI     BsePI     BseRI     BseSI     BseX3I    BseYI
# BsgI      Bsh1285I  BshNI     BshTI     BshVI     BsiEI     BsiHKAI   BsiHKCI
# BsiWI     BsmBI     BsmI      Bso31I    BsoBI     Bsp119I   Bsp120I   Bsp1286I
# Bsp13I    Bsp1407I  Bsp19I    Bsp68I    BspDI     BspEI     BspHI     BspLI
# BspMAI    BspMI     BspOI     BspT104I  BspT107I  BspTI     BspTNI    BsrBI
# BsrDI     BsrFI     BsrGI     BssAI     BssECI    BssHII    BssNAI    BssNI
# BssSI     BssT1I    Bst1107I  Bst2BI    Bst6I     BstACI    BstAFI    BstAUI
# BstBAI    BstBI     BstC8I    BstDSI    BstH2I    BstMCI    BstNSI    BstSFI
# BstSLI    BstSNI    BstV2I    BstX2I    BstYI     BstZ17I   BstZI     Bsu15I
# BsuI      BsuTUI    BtgI      BtgZI     BtrI      BtsI      BtuMI     BveI
# Cac8I     CciI      Cfr10I    Cfr42I    Cfr9I     ClaI      CspAI     DinI
# DraI      EaeI      EagI      Eam1104I  EarI      EciI      Ecl136II  EclXI
# Eco105I   Eco130I   Eco147I   Eco24I    Eco31I    Eco32I    Eco47III  Eco52I
# Eco53kI   Eco57I    Eco72I    Eco88I    EcoICRI   EcoRI     EcoRV     EcoT14I
# EcoT22I   EcoT38I   EgeI      EheI      ErhI      Esp3I     FauNDI    FbaI
# FblI      FriOI     FspI      GsaI      GsuI      HaeII     Hin1I     HincII
# HindII    HindIII   HpaI      Hpy166II  Hpy188III Hpy8I     Hsp92I    KasI
# Kpn2I     KpnI      KroI      Ksp22I    KspAI     KspI      MbiI      MfeI
# MflI      MhlI      MlsI      MluI      MluNI     Mly113I   MmeI      Mox20I
# Mph1103I  MroI      MroNI     MscI      Msp20I    MspA1I    MspCI     MunI
# Mva1269I  NaeI      NarI      NcoI      NdeI      NgoMIV    NheI      NlaIV
# NmeAIII   NruI      NsbI      NsiI      NspI      NspV      PaeI      PaeR7I
# PagI      PauI      PceI      PciI      PctI      PdiI      Pfl23II   PinAI
# Ple19I    PluTI     PmaCI     PmlI      Ppu21I    PscI      PshBI     PsiI
# Psp124BI  Psp1406I  PspCI     PspFI     PspLI     PspN4I    PspOMI    PstI
# PsuI      PteI      PvuI      PvuII     RruI      SacI      SacII     SalI
# ScaI      SduI      SfcI      SfoI      Sfr274I   Sfr303I   SfuI      SgrBI
# SlaI      SmaI      SmlI      SmoI      SnaBI     SpeI      SphI      SseBI
# SspDI     SspI      SstI      StuI      StyI      TaqII     TatI      TspMI
# Vha464I   VneI      VspI      XapI      XbaI      XceI      XhoI      XmaI
# XmaJI     XmiI      ZraI      ZrmI      Zsp2I     AarI      AxyI      BbvCI
# BlpI      Bpu10I    Bpu1102I  Bse21I    Bsp1720I  BspQI     BstEII    BstPI
# Bsu36I    CpoI      CsiI      CspI      Eco81I    Eco91I    EcoO109I  EcoO65I
# KflI      LguI      MabI      PasI      PciSI     PfoI      PpuMI     Psp5II
# PspEI     PspPPI    Rsr2I     RsrII     SapI      SexAI     AbsI      AscI
# AsiSI     CciNI     FseI      FspAI     MauBI     MreI      MssI      NotI
# PacI      PalAI     PmeI      PspXI     RgaI      RigI      SbfI      SdaI
# SfaAI     SgfI      SgrAI     SgrDI     SgsI      SmiI      SrfI      Sse8387I
# SwaI      AdeI      AlwNI     CaiI      DraIII    MteI      PflFI     PstNI
# PsyI      Tth111I   AleI      Asp700I   BoxI      BsaBI     Bse8I     BseJI
# BstPAI    MroXI     MslI      OliI      PdmI      PshAI     RseI      SmiMI
# XmnI      AccB7I    AfiI      AhdI      BaeI      BglI      BmeRI     BplI
# BsaXI     Bsc4I     BseLI     BslI      BstAPI    BstENI    BstMWI    DriI
# Eam1105I  EcoNI     FalI      HpyF10VI  MwoI      PflMI     Van91I    XagI
# AasI      BcgI      BstXI     CspCI     DrdI      DseDI     AloI      ArsI
# BarI      PcsI      PsrI      SfiI      AjuI      XcmI
#
#
# Proposed sequence enzymes: AbaSI, NlaIII, CviAII, FaiI, FatI, FaeI, Hsp92II, Hin1II
# Enzimes only in original sequence:
# Enzimes only in proposed sequence:
# =========================
#
#
# Original sequence enzymes: Hin1II, NlaIII, FaeI, AbaSI, CviAII, FaiI, FatI, HpyCH4V, Hsp92II
#
#    4 MaeII AbaSI HpyCH4IV HpySE526I
#    |
#    |  7 TaiI SetI
#    |  |
#    |  |  10 FatI
#    |  |  |
#    |  |  |11 CviAII
#    |  |  ||
#    |  |  ||12 FaiI
#    |  |  |||
#    |  |  ||| 14 Hin1II NlaIII FaeI HpyCH4V Hsp92II
#    |  |  ||| |
# ATACGTTGCCATGCA
# |||||||||||||||
# TATGCAACGGTACGT
# 1                           15
#
#
#    Enzymes which do not cut the sequence.
#
# FspEI     AccII     AciI      AfaI      AluBI     AluI      AoxI      AspLEI
# BfaI      BfuCI     Bsh1236I  BshFI     BsiSI     BsnI      Bsp143I   BspACI
# BspANI    BspFNI    BssMI     BstFNI    BstHHI    BstKTI    BstMBI    BstUI
# BsuRI     CfoI      Csp6I     CviJI     CviKI_1   CviQI     DpnI      DpnII
# FspBI     GlaI      HaeIII    HapII     HhaI      Hin6I     HinP1I    HpaII
# HspAI     Kzo9I     LpnPI     MaeI      MalI      MboI      MluCI     MnlI
# MseI      MspI      MspJI     MvnI      NdeII     RsaI      RsaNI     SaqAI
# Sau3AI    SgeI      Sse9I     SsiI      SspMI     TaqI      TasI      Tru1I
# Tru9I     XspI      AclWI     AgsI      AjnI      Alw26I    AlwI      ApeKI
# AspS9I    AsuC2I    AsuHPI    AvaII     BbvI      BccI      BceAI     BciT130I
# BcnI      BcoDI     BisI      BlsI      Bme1390I  Bme18I    BmgT120I  BmrFI
# BmsI      BpuMI     Bse1I     BseBI     BseGI     BseMII    BseNI     BseXI
# BslFI     BsmAI     BsmFI     BspCNI    BspPI     BsrI      Bst2UI    Bst4CI
# BstDEI    BstF5I    BstMAI    BstNI     BstSCI    BstV1I    BtsCI     BtsIMutI
# Cfr13I    CseI      DdeI      Eco47I    EcoRII    FaqI      FauI      Fnu4HI
# FokI      Fsp4HI    GluI      HgaI      HinfI     HphI      Hpy188I   Hpy99I
# HpyAV     HpyCH4III HpyF3I    LmnI      Lsp1109I  LweI      MaeIII    MboII
# MlyI      MspR9I    MvaI      NciI      NmuCI     PfeI      PkrI      PleI
# PpsI      Psp6I     PspGI     PspPI     SatI      Sau96I    SchI      ScrFI
# SfaNI     SinI      StyD4I    TaaI      TauI      TfiI      TscAI     TseFI
# TseI      Tsp45I    TspDTI    TspGWI    TspRI     VpaK11BI  AanI      AatII
# Acc16I    Acc36I    Acc65I    AccB1I    AccBSI    AccI      AccIII    AclI
# AcoI      AcsI      AcuI      AcvI      AcyI      AfeI      AflII     AflIII
# AgeI      AhlI      AjiI      Alw21I    Alw44I    Ama87I    Aor13HI   Aor51HI
# ApaI      ApaLI     ApoI      AseI      AsiGI     Asp718I   AspA2I    AsuII
# AsuNHI    AvaI      AvrII     BaeGI     BalI      BamHI     BanI      BanII
# BauI      BbrPI     BbsI      Bbv12I    BciVI     BclI      BcuI      BfmI
# BfoI      BfrI      BfuAI     BfuI      BglII     BlnI      BmcAI     BmeT110I
# BmgBI     BmiI      BmrI      BmtI      BmuI      BpiI      BpmI      Bpu14I
# BpuEI     Bsa29I    BsaAI     BsaHI     BsaI      BsaJI     BsaWI     Bse118I
# Bse3DI    BseAI     BseCI     BseDI     BseMI     BsePI     BseRI     BseSI
# BseX3I    BseYI     BsgI      Bsh1285I  BshNI     BshTI     BshVI     BsiEI
# BsiHKAI   BsiHKCI   BsiWI     BsmBI     BsmI      Bso31I    BsoBI     Bsp119I
# Bsp120I   Bsp1286I  Bsp13I    Bsp1407I  Bsp19I    Bsp68I    BspDI     BspEI
# BspHI     BspLI     BspMAI    BspMI     BspOI     BspT104I  BspT107I  BspTI
# BspTNI    BsrBI     BsrDI     BsrFI     BsrGI     BssAI     BssECI    BssHII
# BssNAI    BssNI     BssSI     BssT1I    Bst1107I  Bst2BI    Bst6I     BstACI
# BstAFI    BstAUI    BstBAI    BstBI     BstC8I    BstDSI    BstH2I    BstMCI
# BstNSI    BstSFI    BstSLI    BstSNI    BstV2I    BstX2I    BstYI     BstZ17I
# BstZI     Bsu15I    BsuI      BsuTUI    BtgI      BtgZI     BtrI      BtsI
# BtuMI     BveI      Cac8I     CciI      Cfr10I    Cfr42I    Cfr9I     ClaI
# CspAI     DinI      DraI      EaeI      EagI      Eam1104I  EarI      EciI
# Ecl136II  EclXI     Eco105I   Eco130I   Eco147I   Eco24I    Eco31I    Eco32I
# Eco47III  Eco52I    Eco53kI   Eco57I    Eco72I    Eco88I    EcoICRI   EcoRI
# EcoRV     EcoT14I   EcoT22I   EcoT38I   EgeI      EheI      ErhI      Esp3I
# FauNDI    FbaI      FblI      FriOI     FspI      GsaI      GsuI      HaeII
# Hin1I     HincII    HindII    HindIII   HpaI      Hpy166II  Hpy188III Hpy8I
# Hsp92I    KasI      Kpn2I     KpnI      KroI      Ksp22I    KspAI     KspI
# MbiI      MfeI      MflI      MhlI      MlsI      MluI      MluNI     Mly113I
# MmeI      Mox20I    Mph1103I  MroI      MroNI     MscI      Msp20I    MspA1I
# MspCI     MunI      Mva1269I  NaeI      NarI      NcoI      NdeI      NgoMIV
# NheI      NlaIV     NmeAIII   NruI      NsbI      NsiI      NspI      NspV
# PaeI      PaeR7I    PagI      PauI      PceI      PciI      PctI      PdiI
# Pfl23II   PinAI     Ple19I    PluTI     PmaCI     PmlI      Ppu21I    PscI
# PshBI     PsiI      Psp124BI  Psp1406I  PspCI     PspFI     PspLI     PspN4I
# PspOMI    PstI      PsuI      PteI      PvuI      PvuII     RruI      SacI
# SacII     SalI      ScaI      SduI      SfcI      SfoI      Sfr274I   Sfr303I
# SfuI      SgrBI     SlaI      SmaI      SmlI      SmoI      SnaBI     SpeI
# SphI      SseBI     SspDI     SspI      SstI      StuI      StyI      TaqII
# TatI      TspMI     Vha464I   VneI      VspI      XapI      XbaI      XceI
# XhoI      XmaI      XmaJI     XmiI      ZraI      ZrmI      Zsp2I     AarI
# AxyI      BbvCI     BlpI      Bpu10I    Bpu1102I  Bse21I    Bsp1720I  BspQI
# BstEII    BstPI     Bsu36I    CpoI      CsiI      CspI      Eco81I    Eco91I
# EcoO109I  EcoO65I   KflI      LguI      MabI      PasI      PciSI     PfoI
# PpuMI     Psp5II    PspEI     PspPPI    Rsr2I     RsrII     SapI      SexAI
# AbsI      AscI      AsiSI     CciNI     FseI      FspAI     MauBI     MreI
# MssI      NotI      PacI      PalAI     PmeI      PspXI     RgaI      RigI
# SbfI      SdaI      SfaAI     SgfI      SgrAI     SgrDI     SgsI      SmiI
# SrfI      Sse8387I  SwaI      AdeI      AlwNI     CaiI      DraIII    MteI
# PflFI     PstNI     PsyI      Tth111I   AleI      Asp700I   BoxI      BsaBI
# Bse8I     BseJI     BstPAI    MroXI     MslI      OliI      PdmI      PshAI
# RseI      SmiMI     XmnI      AccB7I    AfiI      AhdI      BaeI      BglI
# BmeRI     BplI      BsaXI     Bsc4I     BseLI     BslI      BstAPI    BstENI
# BstMWI    DriI      Eam1105I  EcoNI     FalI      HpyF10VI  MwoI      PflMI
# Van91I    XagI      AasI      BcgI      BstXI     CspCI     DrdI      DseDI
# AloI      ArsI      BarI      PcsI      PsrI      SfiI      AjuI      XcmI
#
#
#
# Proposed sequence enzymes: MaeII, NlaIII, AbaSI, CviAII, HpyCH4IV, TaiI, FaeI, HpySE526I, FaiI, FatI, Hsp92II, HpyCH4V, SetI, Hin1II
# Enzimes only in original sequence:
# Enzimes only in proposed sequence:
# =========================
#
#
# Original sequence enzymes: Hin1II, NlaIII, FaeI, AbaSI, CviAII, FaiI, FatI, HpyCH4V, Hsp92II
#
#    4 AciI AbaSI BspACI SsiI
#    |
#    | 6 AbaSI MspA1I
#    | |
#    | |   10 FatI
#    | |   |
#    | |   |11 CviAII
#    | |   ||
#    | |   ||12 FaiI
#    | |   |||
#    | |   ||| 14 Hin1II NlaIII FaeI Hsp92II
#    | |   ||| |
#    | |   ||| |15 AbaSI
#    | |   ||| ||
# ATCCGCTGTCATGCG
# |||||||||||||||
# TAGGCGACAGTACGC
# 1                           15
#
#
#    Enzymes which do not cut the sequence.
#
# FspEI     AccII     AfaI      AluBI     AluI      AoxI      AspLEI    BfaI
# BfuCI     Bsh1236I  BshFI     BsiSI     BsnI      Bsp143I   BspANI    BspFNI
# BssMI     BstFNI    BstHHI    BstKTI    BstMBI    BstUI     BsuRI     CfoI
# Csp6I     CviJI     CviKI_1   CviQI     DpnI      DpnII     FspBI     GlaI
# HaeIII    HapII     HhaI      Hin6I     HinP1I    HpaII     HpyCH4IV  HpyCH4V
# HpySE526I HspAI     Kzo9I     LpnPI     MaeI      MaeII     MalI      MboI
# MluCI     MnlI      MseI      MspI      MspJI     MvnI      NdeII     RsaI
# RsaNI     SaqAI     Sau3AI    SetI      SgeI      Sse9I     SspMI     TaiI
# TaqI      TasI      Tru1I     Tru9I     XspI      AclWI     AgsI      AjnI
# Alw26I    AlwI      ApeKI     AspS9I    AsuC2I    AsuHPI    AvaII     BbvI
# BccI      BceAI     BciT130I  BcnI      BcoDI     BisI      BlsI      Bme1390I
# Bme18I    BmgT120I  BmrFI     BmsI      BpuMI     Bse1I     BseBI     BseGI
# BseMII    BseNI     BseXI     BslFI     BsmAI     BsmFI     BspCNI    BspPI
# BsrI      Bst2UI    Bst4CI    BstDEI    BstF5I    BstMAI    BstNI     BstSCI
# BstV1I    BtsCI     BtsIMutI  Cfr13I    CseI      DdeI      Eco47I    EcoRII
# FaqI      FauI      Fnu4HI    FokI      Fsp4HI    GluI      HgaI      HinfI
# HphI      Hpy188I   Hpy99I    HpyAV     HpyCH4III HpyF3I    LmnI      Lsp1109I
# LweI      MaeIII    MboII     MlyI      MspR9I    MvaI      NciI      NmuCI
# PfeI      PkrI      PleI      PpsI      Psp6I     PspGI     PspPI     SatI
# Sau96I    SchI      ScrFI     SfaNI     SinI      StyD4I    TaaI      TauI
# TfiI      TscAI     TseFI     TseI      Tsp45I    TspDTI    TspGWI    TspRI
# VpaK11BI  AanI      AatII     Acc16I    Acc36I    Acc65I    AccB1I    AccBSI
# AccI      AccIII    AclI      AcoI      AcsI      AcuI      AcvI      AcyI
# AfeI      AflII     AflIII    AgeI      AhlI      AjiI      Alw21I    Alw44I
# Ama87I    Aor13HI   Aor51HI   ApaI      ApaLI     ApoI      AseI      AsiGI
# Asp718I   AspA2I    AsuII     AsuNHI    AvaI      AvrII     BaeGI     BalI
# BamHI     BanI      BanII     BauI      BbrPI     BbsI      Bbv12I    BciVI
# BclI      BcuI      BfmI      BfoI      BfrI      BfuAI     BfuI      BglII
# BlnI      BmcAI     BmeT110I  BmgBI     BmiI      BmrI      BmtI      BmuI
# BpiI      BpmI      Bpu14I    BpuEI     Bsa29I    BsaAI     BsaHI     BsaI
# BsaJI     BsaWI     Bse118I   Bse3DI    BseAI     BseCI     BseDI     BseMI
# BsePI     BseRI     BseSI     BseX3I    BseYI     BsgI      Bsh1285I  BshNI
# BshTI     BshVI     BsiEI     BsiHKAI   BsiHKCI   BsiWI     BsmBI     BsmI
# Bso31I    BsoBI     Bsp119I   Bsp120I   Bsp1286I  Bsp13I    Bsp1407I  Bsp19I
# Bsp68I    BspDI     BspEI     BspHI     BspLI     BspMAI    BspMI     BspOI
# BspT104I  BspT107I  BspTI     BspTNI    BsrBI     BsrDI     BsrFI     BsrGI
# BssAI     BssECI    BssHII    BssNAI    BssNI     BssSI     BssT1I    Bst1107I
# Bst2BI    Bst6I     BstACI    BstAFI    BstAUI    BstBAI    BstBI     BstC8I
# BstDSI    BstH2I    BstMCI    BstNSI    BstSFI    BstSLI    BstSNI    BstV2I
# BstX2I    BstYI     BstZ17I   BstZI     Bsu15I    BsuI      BsuTUI    BtgI
# BtgZI     BtrI      BtsI      BtuMI     BveI      Cac8I     CciI      Cfr10I
# Cfr42I    Cfr9I     ClaI      CspAI     DinI      DraI      EaeI      EagI
# Eam1104I  EarI      EciI      Ecl136II  EclXI     Eco105I   Eco130I   Eco147I
# Eco24I    Eco31I    Eco32I    Eco47III  Eco52I    Eco53kI   Eco57I    Eco72I
# Eco88I    EcoICRI   EcoRI     EcoRV     EcoT14I   EcoT22I   EcoT38I   EgeI
# EheI      ErhI      Esp3I     FauNDI    FbaI      FblI      FriOI     FspI
# GsaI      GsuI      HaeII     Hin1I     HincII    HindII    HindIII   HpaI
# Hpy166II  Hpy188III Hpy8I     Hsp92I    KasI      Kpn2I     KpnI      KroI
# Ksp22I    KspAI     KspI      MbiI      MfeI      MflI      MhlI      MlsI
# MluI      MluNI     Mly113I   MmeI      Mox20I    Mph1103I  MroI      MroNI
# MscI      Msp20I    MspCI     MunI      Mva1269I  NaeI      NarI      NcoI
# NdeI      NgoMIV    NheI      NlaIV     NmeAIII   NruI      NsbI      NsiI
# NspI      NspV      PaeI      PaeR7I    PagI      PauI      PceI      PciI
# PctI      PdiI      Pfl23II   PinAI     Ple19I    PluTI     PmaCI     PmlI
# Ppu21I    PscI      PshBI     PsiI      Psp124BI  Psp1406I  PspCI     PspFI
# PspLI     PspN4I    PspOMI    PstI      PsuI      PteI      PvuI      PvuII
# RruI      SacI      SacII     SalI      ScaI      SduI      SfcI      SfoI
# Sfr274I   Sfr303I   SfuI      SgrBI     SlaI      SmaI      SmlI      SmoI
# SnaBI     SpeI      SphI      SseBI     SspDI     SspI      SstI      StuI
# StyI      TaqII     TatI      TspMI     Vha464I   VneI      VspI      XapI
# XbaI      XceI      XhoI      XmaI      XmaJI     XmiI      ZraI      ZrmI
# Zsp2I     AarI      AxyI      BbvCI     BlpI      Bpu10I    Bpu1102I  Bse21I
# Bsp1720I  BspQI     BstEII    BstPI     Bsu36I    CpoI      CsiI      CspI
# Eco81I    Eco91I    EcoO109I  EcoO65I   KflI      LguI      MabI      PasI
# PciSI     PfoI      PpuMI     Psp5II    PspEI     PspPPI    Rsr2I     RsrII
# SapI      SexAI     AbsI      AscI      AsiSI     CciNI     FseI      FspAI
# MauBI     MreI      MssI      NotI      PacI      PalAI     PmeI      PspXI
# RgaI      RigI      SbfI      SdaI      SfaAI     SgfI      SgrAI     SgrDI
# SgsI      SmiI      SrfI      Sse8387I  SwaI      AdeI      AlwNI     CaiI
# DraIII    MteI      PflFI     PstNI     PsyI      Tth111I   AleI      Asp700I
# BoxI      BsaBI     Bse8I     BseJI     BstPAI    MroXI     MslI      OliI
# PdmI      PshAI     RseI      SmiMI     XmnI      AccB7I    AfiI      AhdI
# BaeI      BglI      BmeRI     BplI      BsaXI     Bsc4I     BseLI     BslI
# BstAPI    BstENI    BstMWI    DriI      Eam1105I  EcoNI     FalI      HpyF10VI
# MwoI      PflMI     Van91I    XagI      AasI      BcgI      BstXI     CspCI
# DrdI      DseDI     AloI      ArsI      BarI      PcsI      PsrI      SfiI
# AjuI      XcmI
#
#
# Proposed sequence enzymes: BspACI, AbaSI, NlaIII, CviAII, FaiI, FatI, AciI, FaeI, SsiI, Hsp92II, MspA1I, Hin1II
# Enzimes only in original sequence:
# Enzimes only in proposed sequence:
# =========================
#
#
# Original sequence enzymes: Hin1II, NlaIII, FaeI, AbaSI, CviAII, FaiI, FatI, HpyCH4V, Hsp92II
#
#    4 TaqI AbaSI
#    |
#    |     10 FatI
#    |     |
#    |     |11 CviAII
#    |     ||
#    |     ||12 FaiI
#    |     |||
#    |     ||| 14 Hin1II NlaIII FaeI HpyCH4V Hsp92II
#    |     ||| |
# ATTCGATGTCATGCA
# |||||||||||||||
# TAAGCTACAGTACGT
# 1                           15
#
#
#    Enzymes which do not cut the sequence.
#
# FspEI     AccII     AciI      AfaI      AluBI     AluI      AoxI      AspLEI
# BfaI      BfuCI     Bsh1236I  BshFI     BsiSI     BsnI      Bsp143I   BspACI
# BspANI    BspFNI    BssMI     BstFNI    BstHHI    BstKTI    BstMBI    BstUI
# BsuRI     CfoI      Csp6I     CviJI     CviKI_1   CviQI     DpnI      DpnII
# FspBI     GlaI      HaeIII    HapII     HhaI      Hin6I     HinP1I    HpaII
# HpyCH4IV  HpySE526I HspAI     Kzo9I     LpnPI     MaeI      MaeII     MalI
# MboI      MluCI     MnlI      MseI      MspI      MspJI     MvnI      NdeII
# RsaI      RsaNI     SaqAI     Sau3AI    SetI      SgeI      Sse9I     SsiI
# SspMI     TaiI      TasI      Tru1I     Tru9I     XspI      AclWI     AgsI
# AjnI      Alw26I    AlwI      ApeKI     AspS9I    AsuC2I    AsuHPI    AvaII
# BbvI      BccI      BceAI     BciT130I  BcnI      BcoDI     BisI      BlsI
# Bme1390I  Bme18I    BmgT120I  BmrFI     BmsI      BpuMI     Bse1I     BseBI
# BseGI     BseMII    BseNI     BseXI     BslFI     BsmAI     BsmFI     BspCNI
# BspPI     BsrI      Bst2UI    Bst4CI    BstDEI    BstF5I    BstMAI    BstNI
# BstSCI    BstV1I    BtsCI     BtsIMutI  Cfr13I    CseI      DdeI      Eco47I
# EcoRII    FaqI      FauI      Fnu4HI    FokI      Fsp4HI    GluI      HgaI
# HinfI     HphI      Hpy188I   Hpy99I    HpyAV     HpyCH4III HpyF3I    LmnI
# Lsp1109I  LweI      MaeIII    MboII     MlyI      MspR9I    MvaI      NciI
# NmuCI     PfeI      PkrI      PleI      PpsI      Psp6I     PspGI     PspPI
# SatI      Sau96I    SchI      ScrFI     SfaNI     SinI      StyD4I    TaaI
# TauI      TfiI      TscAI     TseFI     TseI      Tsp45I    TspDTI    TspGWI
# TspRI     VpaK11BI  AanI      AatII     Acc16I    Acc36I    Acc65I    AccB1I
# AccBSI    AccI      AccIII    AclI      AcoI      AcsI      AcuI      AcvI
# AcyI      AfeI      AflII     AflIII    AgeI      AhlI      AjiI      Alw21I
# Alw44I    Ama87I    Aor13HI   Aor51HI   ApaI      ApaLI     ApoI      AseI
# AsiGI     Asp718I   AspA2I    AsuII     AsuNHI    AvaI      AvrII     BaeGI
# BalI      BamHI     BanI      BanII     BauI      BbrPI     BbsI      Bbv12I
# BciVI     BclI      BcuI      BfmI      BfoI      BfrI      BfuAI     BfuI
# BglII     BlnI      BmcAI     BmeT110I  BmgBI     BmiI      BmrI      BmtI
# BmuI      BpiI      BpmI      Bpu14I    BpuEI     Bsa29I    BsaAI     BsaHI
# BsaI      BsaJI     BsaWI     Bse118I   Bse3DI    BseAI     BseCI     BseDI
# BseMI     BsePI     BseRI     BseSI     BseX3I    BseYI     BsgI      Bsh1285I
# BshNI     BshTI     BshVI     BsiEI     BsiHKAI   BsiHKCI   BsiWI     BsmBI
# BsmI      Bso31I    BsoBI     Bsp119I   Bsp120I   Bsp1286I  Bsp13I    Bsp1407I
# Bsp19I    Bsp68I    BspDI     BspEI     BspHI     BspLI     BspMAI    BspMI
# BspOI     BspT104I  BspT107I  BspTI     BspTNI    BsrBI     BsrDI     BsrFI
# BsrGI     BssAI     BssECI    BssHII    BssNAI    BssNI     BssSI     BssT1I
# Bst1107I  Bst2BI    Bst6I     BstACI    BstAFI    BstAUI    BstBAI    BstBI
# BstC8I    BstDSI    BstH2I    BstMCI    BstNSI    BstSFI    BstSLI    BstSNI
# BstV2I    BstX2I    BstYI     BstZ17I   BstZI     Bsu15I    BsuI      BsuTUI
# BtgI      BtgZI     BtrI      BtsI      BtuMI     BveI      Cac8I     CciI
# Cfr10I    Cfr42I    Cfr9I     ClaI      CspAI     DinI      DraI      EaeI
# EagI      Eam1104I  EarI      EciI      Ecl136II  EclXI     Eco105I   Eco130I
# Eco147I   Eco24I    Eco31I    Eco32I    Eco47III  Eco52I    Eco53kI   Eco57I
# Eco72I    Eco88I    EcoICRI   EcoRI     EcoRV     EcoT14I   EcoT22I   EcoT38I
# EgeI      EheI      ErhI      Esp3I     FauNDI    FbaI      FblI      FriOI
# FspI      GsaI      GsuI      HaeII     Hin1I     HincII    HindII    HindIII
# HpaI      Hpy166II  Hpy188III Hpy8I     Hsp92I    KasI      Kpn2I     KpnI
# KroI      Ksp22I    KspAI     KspI      MbiI      MfeI      MflI      MhlI
# MlsI      MluI      MluNI     Mly113I   MmeI      Mox20I    Mph1103I  MroI
# MroNI     MscI      Msp20I    MspA1I    MspCI     MunI      Mva1269I  NaeI
# NarI      NcoI      NdeI      NgoMIV    NheI      NlaIV     NmeAIII   NruI
# NsbI      NsiI      NspI      NspV      PaeI      PaeR7I    PagI      PauI
# PceI      PciI      PctI      PdiI      Pfl23II   PinAI     Ple19I    PluTI
# PmaCI     PmlI      Ppu21I    PscI      PshBI     PsiI      Psp124BI  Psp1406I
# PspCI     PspFI     PspLI     PspN4I    PspOMI    PstI      PsuI      PteI
# PvuI      PvuII     RruI      SacI      SacII     SalI      ScaI      SduI
# SfcI      SfoI      Sfr274I   Sfr303I   SfuI      SgrBI     SlaI      SmaI
# SmlI      SmoI      SnaBI     SpeI      SphI      SseBI     SspDI     SspI
# SstI      StuI      StyI      TaqII     TatI      TspMI     Vha464I   VneI
# ...
# Psp124BI  Psp1406I  PspCI     PspFI     PspLI     PspN4I    PspOMI    PstI
# PsuI      PteI      PvuI      PvuII     RruI      SacI      SacII     SalI
# ScaI      SduI      SfcI      SfoI      Sfr274I   Sfr303I   SfuI      SgrBI
# SlaI      SmaI      SmlI      SmoI      SnaBI     SpeI      SphI      SseBI
# SspDI     SspI      SstI      StuI      StyI      TaqII     TatI      TspMI
# Vha464I   VneI      VspI      XapI      XbaI      XceI      XhoI      XmaI
# XmaJI     XmiI      ZraI      ZrmI      Zsp2I     AarI      AxyI      BbvCI
# BlpI      Bpu10I    Bpu1102I  Bse21I    Bsp1720I  BspQI     BstEII    BstPI
# Bsu36I    CpoI      CsiI      CspI      Eco81I    Eco91I    EcoO109I  EcoO65I
# KflI      LguI      MabI      PasI      PciSI     PfoI      PpuMI     Psp5II
# PspEI     PspPPI    Rsr2I     RsrII     SapI      SexAI     AbsI      AscI
# AsiSI     CciNI     FseI      FspAI     MauBI     MreI      MssI      NotI
# PacI      PalAI     PmeI      PspXI     RgaI      RigI      SbfI      SdaI
# SfaAI     SgfI      SgrAI     SgrDI     SgsI      SmiI      SrfI      Sse8387I
# SwaI      AdeI      AlwNI     CaiI      DraIII    MteI      PflFI     PstNI
# PsyI      Tth111I   AleI      Asp700I   BoxI      BsaBI     Bse8I     BseJI
# BstPAI    MroXI     MslI      OliI      PdmI      PshAI     RseI      SmiMI
# XmnI      AccB7I    AfiI      AhdI      BaeI      BglI      BmeRI     BplI
# BsaXI     Bsc4I     BseLI     BslI      BstAPI    BstENI    BstMWI    DriI
# Eam1105I  EcoNI     FalI      HpyF10VI  MwoI      PflMI     Van91I    XagI
# AasI      BcgI      BstXI     CspCI     DrdI      DseDI     AloI      ArsI
# BarI      PcsI      PsrI      SfiI      AjuI      XcmI
#
#
# Proposed sequence enzymes: AbaSI, NlaIII, CviAII, FaiI, FatI, FaeI, Hsp92II, Hin1II
# Enzimes only in original sequence:
# Enzimes only in proposed sequence:
# =========================
#
#
# Original sequence enzymes: Hin1II, NlaIII, FaeI, AbaSI, CviAII, FaiI, FatI, HpyCH4V, Hsp92II
#
#    4 MaeII AbaSI HpyCH4IV HpySE526I
#    |
#    | 6 AbaSI
#    | |
#    | |7 TaiI SetI
#    | ||
#    | ||  10 FatI
#    | ||  |
#    | ||  |11 CviAII
#    | ||  ||
#    | ||  ||12 FaiI
#    | ||  |||
#    | ||  ||| 14 Hin1II NlaIII FaeI Hsp92II
#    | ||  ||| |
# ATACGTTGTCATGCG
# |||||||||||||||
# TATGCAACAGTACGC
# 1                           15
#
#
#    Enzymes which do not cut the sequence.
#
# FspEI     AccII     AciI      AfaI      AluBI     AluI      AoxI      AspLEI
# BfaI      BfuCI     Bsh1236I  BshFI     BsiSI     BsnI      Bsp143I   BspACI
# BspANI    BspFNI    BssMI     BstFNI    BstHHI    BstKTI    BstMBI    BstUI
# BsuRI     CfoI      Csp6I     CviJI     CviKI_1   CviQI     DpnI      DpnII
# FspBI     GlaI      HaeIII    HapII     HhaI      Hin6I     HinP1I    HpaII
# HpyCH4V   HspAI     Kzo9I     LpnPI     MaeI      MalI      MboI      MluCI
# MnlI      MseI      MspI      MspJI     MvnI      NdeII     RsaI      RsaNI
# SaqAI     Sau3AI    SgeI      Sse9I     SsiI      SspMI     TaqI      TasI
# Tru1I     Tru9I     XspI      AclWI     AgsI      AjnI      Alw26I    AlwI
# ApeKI     AspS9I    AsuC2I    AsuHPI    AvaII     BbvI      BccI      BceAI
# BciT130I  BcnI      BcoDI     BisI      BlsI      Bme1390I  Bme18I    BmgT120I
# BmrFI     BmsI      BpuMI     Bse1I     BseBI     BseGI     BseMII    BseNI
# BseXI     BslFI     BsmAI     BsmFI     BspCNI    BspPI     BsrI      Bst2UI
# Bst4CI    BstDEI    BstF5I    BstMAI    BstNI     BstSCI    BstV1I    BtsCI
# BtsIMutI  Cfr13I    CseI      DdeI      Eco47I    EcoRII    FaqI      FauI
# Fnu4HI    FokI      Fsp4HI    GluI      HgaI      HinfI     HphI      Hpy188I
# Hpy99I    HpyAV     HpyCH4III HpyF3I    LmnI      Lsp1109I  LweI      MaeIII
# MboII     MlyI      MspR9I    MvaI      NciI      NmuCI     PfeI      PkrI
# PleI      PpsI      Psp6I     PspGI     PspPI     SatI      Sau96I    SchI
# ScrFI     SfaNI     SinI      StyD4I    TaaI      TauI      TfiI      TscAI
# TseFI     TseI      Tsp45I    TspDTI    TspGWI    TspRI     VpaK11BI  AanI
# AatII     Acc16I    Acc36I    Acc65I    AccB1I    AccBSI    AccI      AccIII
# AclI      AcoI      AcsI      AcuI      AcvI      AcyI      AfeI      AflII
# AflIII    AgeI      AhlI      AjiI      Alw21I    Alw44I    Ama87I    Aor13HI
# Aor51HI   ApaI      ApaLI     ApoI      AseI      AsiGI     Asp718I   AspA2I
# AsuII     AsuNHI    AvaI      AvrII     BaeGI     BalI      BamHI     BanI
# BanII     BauI      BbrPI     BbsI      Bbv12I    BciVI     BclI      BcuI
# BfmI      BfoI      BfrI      BfuAI     BfuI      BglII     BlnI      BmcAI
# BmeT110I  BmgBI     BmiI      BmrI      BmtI      BmuI      BpiI      BpmI
# Bpu14I    BpuEI     Bsa29I    BsaAI     BsaHI     BsaI      BsaJI     BsaWI
# Bse118I   Bse3DI    BseAI     BseCI     BseDI     BseMI     BsePI     BseRI
# BseSI     BseX3I    BseYI     BsgI      Bsh1285I  BshNI     BshTI     BshVI
# BsiEI     BsiHKAI   BsiHKCI   BsiWI     BsmBI     BsmI      Bso31I    BsoBI
# Bsp119I   Bsp120I   Bsp1286I  Bsp13I    Bsp1407I  Bsp19I    Bsp68I    BspDI
# BspEI     BspHI     BspLI     BspMAI    BspMI     BspOI     BspT104I  BspT107I
# BspTI     BspTNI    BsrBI     BsrDI     BsrFI     BsrGI     BssAI     BssECI
# BssHII    BssNAI    BssNI     BssSI     BssT1I    Bst1107I  Bst2BI    Bst6I
# BstACI    BstAFI    BstAUI    BstBAI    BstBI     BstC8I    BstDSI    BstH2I
# BstMCI    BstNSI    BstSFI    BstSLI    BstSNI    BstV2I    BstX2I    BstYI
# BstZ17I   BstZI     Bsu15I    BsuI      BsuTUI    BtgI      BtgZI     BtrI
# BtsI      BtuMI     BveI      Cac8I     CciI      Cfr10I    Cfr42I    Cfr9I
# ClaI      CspAI     DinI      DraI      EaeI      EagI      Eam1104I  EarI
# EciI      Ecl136II  EclXI     Eco105I   Eco130I   Eco147I   Eco24I    Eco31I
# Eco32I    Eco47III  Eco52I    Eco53kI   Eco57I    Eco72I    Eco88I    EcoICRI
# EcoRI     EcoRV     EcoT14I   EcoT22I   EcoT38I   EgeI      EheI      ErhI
# Esp3I     FauNDI    FbaI      FblI      FriOI     FspI      GsaI      GsuI
# HaeII     Hin1I     HincII    HindII    HindIII   HpaI      Hpy166II  Hpy188III
# Hpy8I     Hsp92I    KasI      Kpn2I     KpnI      KroI      Ksp22I    KspAI
# KspI      MbiI      MfeI      MflI      MhlI      MlsI      MluI      MluNI
# Mly113I   MmeI      Mox20I    Mph1103I  MroI      MroNI     MscI      Msp20I
# MspA1I    MspCI     MunI      Mva1269I  NaeI      NarI      NcoI      NdeI
# NgoMIV    NheI      NlaIV     NmeAIII   NruI      NsbI      NsiI      NspI
# NspV      PaeI      PaeR7I    PagI      PauI      PceI      PciI      PctI
# PdiI      Pfl23II   PinAI     Ple19I    PluTI     PmaCI     PmlI      Ppu21I
# PscI      PshBI     PsiI      Psp124BI  Psp1406I  PspCI     PspFI     PspLI
# PspN4I    PspOMI    PstI      PsuI      PteI      PvuI      PvuII     RruI
# SacI      SacII     SalI      ScaI      SduI      SfcI      SfoI      Sfr274I
# Sfr303I   SfuI      SgrBI     SlaI      SmaI      SmlI      SmoI      SnaBI
# SpeI      SphI      SseBI     SspDI     SspI      SstI      StuI      StyI
# TaqII     TatI      TspMI     Vha464I   VneI      VspI      XapI      XbaI
# XceI      XhoI      XmaI      XmaJI     XmiI      ZraI      ZrmI      Zsp2I
# AarI      AxyI      BbvCI     BlpI      Bpu10I    Bpu1102I  Bse21I    Bsp1720I
# BspQI     BstEII    BstPI     Bsu36I    CpoI      CsiI      CspI      Eco81I
# Eco91I    EcoO109I  EcoO65I   KflI      LguI      MabI      PasI      PciSI
# PfoI      PpuMI     Psp5II    PspEI     PspPPI    Rsr2I     RsrII     SapI
# SexAI     AbsI      AscI      AsiSI     CciNI     FseI      FspAI     MauBI
# MreI      MssI      NotI      PacI      PalAI     PmeI      PspXI     RgaI
# RigI      SbfI      SdaI      SfaAI     SgfI      SgrAI     SgrDI     SgsI
# SmiI      SrfI      Sse8387I  SwaI      AdeI      AlwNI     CaiI      DraIII
# MteI      PflFI     PstNI     PsyI      Tth111I   AleI      Asp700I   BoxI
# BsaBI     Bse8I     BseJI     BstPAI    MroXI     MslI      OliI      PdmI
# PshAI     RseI      SmiMI     XmnI      AccB7I    AfiI      AhdI      BaeI
# BglI      BmeRI     BplI      BsaXI     Bsc4I     BseLI     BslI      BstAPI
# BstENI    BstMWI    DriI      Eam1105I  EcoNI     FalI      HpyF10VI  MwoI
# PflMI     Van91I    XagI      AasI      BcgI      BstXI     CspCI     DrdI
# DseDI     AloI      ArsI      BarI      PcsI      PsrI      SfiI      AjuI
# XcmI
#
#
# Proposed sequence enzymes: MaeII, NlaIII, AbaSI, CviAII, HpyCH4IV, TaiI, FaeI, HpySE526I, FaiI, FatI, Hsp92II, SetI, Hin1II
# Enzimes only in original sequence:
# Enzimes only in proposed sequence:
# =========================
#
#
# Original sequence enzymes: Hin1II, NlaIII, FaeI, AbaSI, CviAII, FaiI, FatI, HpyCH4V, Hsp92II
#
#    4 AbaSI
#    |
#    |   8 TseFI NmuCI Tsp45I MaeIII
#    |   |
# ATACGCTGTCACGCC
# |||||||||||||||
# TATGCGACAGTGCGG
# 1                           15
#
#
#    Enzymes which do not cut the sequence.
#
# FspEI     AccII     AciI      AfaI      AluBI     AluI      AoxI      AspLEI
# BfaI      BfuCI     Bsh1236I  BshFI     BsiSI     BsnI      Bsp143I   BspACI
# BspANI    BspFNI    BssMI     BstFNI    BstHHI    BstKTI    BstMBI    BstUI
# BsuRI     CfoI      Csp6I     CviAII    CviJI     CviKI_1   CviQI     DpnI
# DpnII     FaeI      FaiI      FatI      FspBI     GlaI      HaeIII    HapII
# HhaI      Hin1II    Hin6I     HinP1I    HpaII     HpyCH4IV  HpyCH4V   HpySE526I
# Hsp92II   HspAI     Kzo9I     LpnPI     MaeI      MaeII     MalI      MboI
# MluCI     MnlI      MseI      MspI      MspJI     MvnI      NdeII     NlaIII
# RsaI      RsaNI     SaqAI     Sau3AI    SetI      SgeI      Sse9I     SsiI
# SspMI     TaiI      TaqI      TasI      Tru1I     Tru9I     XspI      AclWI
# AgsI      AjnI      Alw26I    AlwI      ApeKI     AspS9I    AsuC2I    AsuHPI
# AvaII     BbvI      BccI      BceAI     BciT130I  BcnI      BcoDI     BisI
# BlsI      Bme1390I  Bme18I    BmgT120I  BmrFI     BmsI      BpuMI     Bse1I
# BseBI     BseGI     BseMII    BseNI     BseXI     BslFI     BsmAI     BsmFI
# BspCNI    BspPI     BsrI      Bst2UI    Bst4CI    BstDEI    BstF5I    BstMAI
# BstNI     BstSCI    BstV1I    BtsCI     BtsIMutI  Cfr13I    CseI      DdeI
# Eco47I    EcoRII    FaqI      FauI      Fnu4HI    FokI      Fsp4HI    GluI
# HgaI      HinfI     HphI      Hpy188I   Hpy99I    HpyAV     HpyCH4III HpyF3I
# LmnI      Lsp1109I  LweI      MboII     MlyI      MspR9I    MvaI      NciI
# PfeI      PkrI      PleI      PpsI      Psp6I     PspGI     PspPI     SatI
# Sau96I    SchI      ScrFI     SfaNI     SinI      StyD4I    TaaI      TauI
# TfiI      TscAI     TseI      TspDTI    TspGWI    TspRI     VpaK11BI  AanI
# AatII     Acc16I    Acc36I    Acc65I    AccB1I    AccBSI    AccI      AccIII
# AclI      AcoI      AcsI      AcuI      AcvI      AcyI      AfeI      AflII
# AflIII    AgeI      AhlI      AjiI      Alw21I    Alw44I    Ama87I    Aor13HI
# Aor51HI   ApaI      ApaLI     ApoI      AseI      AsiGI     Asp718I   AspA2I
# AsuII     AsuNHI    AvaI      AvrII     BaeGI     BalI      BamHI     BanI
# BanII     BauI      BbrPI     BbsI      Bbv12I    BciVI     BclI      BcuI
# BfmI      BfoI      BfrI      BfuAI     BfuI      BglII     BlnI      BmcAI
# BmeT110I  BmgBI     BmiI      BmrI      BmtI      BmuI      BpiI      BpmI
# Bpu14I    BpuEI     Bsa29I    BsaAI     BsaHI     BsaI      BsaJI     BsaWI
# Bse118I   Bse3DI    BseAI     BseCI     BseDI     BseMI     BsePI     BseRI
# BseSI     BseX3I    BseYI     BsgI      Bsh1285I  BshNI     BshTI     BshVI
# BsiEI     BsiHKAI   BsiHKCI   BsiWI     BsmBI     BsmI      Bso31I    BsoBI
# Bsp119I   Bsp120I   Bsp1286I  Bsp13I    Bsp1407I  Bsp19I    Bsp68I    BspDI
# BspEI     BspHI     BspLI     BspMAI    BspMI     BspOI     BspT104I  BspT107I
# BspTI     BspTNI    BsrBI     BsrDI     BsrFI     BsrGI     BssAI     BssECI
# BssHII    BssNAI    BssNI     BssSI     BssT1I    Bst1107I  Bst2BI    Bst6I
# BstACI    BstAFI    BstAUI    BstBAI    BstBI     BstC8I    BstDSI    BstH2I
# BstMCI    BstNSI    BstSFI    BstSLI    BstSNI    BstV2I    BstX2I    BstYI
# BstZ17I   BstZI     Bsu15I    BsuI      BsuTUI    BtgI      BtgZI     BtrI
# BtsI      BtuMI     BveI      Cac8I     CciI      Cfr10I    Cfr42I    Cfr9I
# ClaI      CspAI     DinI      DraI      EaeI      EagI      Eam1104I  EarI
# EciI      Ecl136II  EclXI     Eco105I   Eco130I   Eco147I   Eco24I    Eco31I
# Eco32I    Eco47III  Eco52I    Eco53kI   Eco57I    Eco72I    Eco88I    EcoICRI
# EcoRI     EcoRV     EcoT14I   EcoT22I   EcoT38I   EgeI      EheI      ErhI
# Esp3I     FauNDI    FbaI      FblI      FriOI     FspI      GsaI      GsuI
# HaeII     Hin1I     HincII    HindII    HindIII   HpaI      Hpy166II  Hpy188III
# Hpy8I     Hsp92I    KasI      Kpn2I     KpnI      KroI      Ksp22I    KspAI
# KspI      MbiI      MfeI      MflI      MhlI      MlsI      MluI      MluNI
# Mly113I   MmeI      Mox20I    Mph1103I  MroI      MroNI     MscI      Msp20I
# MspA1I    MspCI     MunI      Mva1269I  NaeI      NarI      NcoI      NdeI
# NgoMIV    NheI      NlaIV     NmeAIII   NruI      NsbI      NsiI      NspI
# NspV      PaeI      PaeR7I    PagI      PauI      PceI      PciI      PctI
# PdiI      Pfl23II   PinAI     Ple19I    PluTI     PmaCI     PmlI      Ppu21I
# PscI      PshBI     PsiI      Psp124BI  Psp1406I  PspCI     PspFI     PspLI
# PspN4I    PspOMI    PstI      PsuI      PteI      PvuI      PvuII     RruI
# SacI      SacII     SalI      ScaI      SduI      SfcI      SfoI      Sfr274I
# Sfr303I   SfuI      SgrBI     SlaI      SmaI      SmlI      SmoI      SnaBI
# SpeI      SphI      SseBI     SspDI     SspI      SstI      StuI      StyI
# TaqII     TatI      TspMI     Vha464I   VneI      VspI      XapI      XbaI
# XceI      XhoI      XmaI      XmaJI     XmiI      ZraI      ZrmI      Zsp2I
# AarI      AxyI      BbvCI     BlpI      Bpu10I    Bpu1102I  Bse21I    Bsp1720I
# BspQI     BstEII    BstPI     Bsu36I    CpoI      CsiI      CspI      Eco81I
# Eco91I    EcoO109I  EcoO65I   KflI      LguI      MabI      PasI      PciSI
# PfoI      PpuMI     Psp5II    PspEI     PspPPI    Rsr2I     RsrII     SapI
# SexAI     AbsI      AscI      AsiSI     CciNI     FseI      FspAI     MauBI
# MreI      MssI      NotI      PacI      PalAI     PmeI      PspXI     RgaI
# RigI      SbfI      SdaI      SfaAI     SgfI      SgrAI     SgrDI     SgsI
# SmiI      SrfI      Sse8387I  SwaI      AdeI      AlwNI     CaiI      DraIII
# MteI      PflFI     PstNI     PsyI      Tth111I   AleI      Asp700I   BoxI
# BsaBI     Bse8I     BseJI     BstPAI    MroXI     MslI      OliI      PdmI
# PshAI     RseI      SmiMI     XmnI      AccB7I    AfiI      AhdI      BaeI
# BglI      BmeRI     BplI      BsaXI     Bsc4I     BseLI     BslI      BstAPI
# BstENI    BstMWI    DriI      Eam1105I  EcoNI     FalI      HpyF10VI  MwoI
# PflMI     Van91I    XagI      AasI      BcgI      BstXI     CspCI     DrdI
# DseDI     AloI      ArsI      BarI      PcsI      PsrI      SfiI      AjuI
# XcmI
#
#
# Proposed sequence enzymes: TseFI, AbaSI, MaeIII, Tsp45I, NmuCI
# Enzimes only in original sequence:
# Enzimes only in proposed sequence:
# =========================
